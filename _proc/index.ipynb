# %% [raw]
# ---
# description: Fast and flexible multi-agent gridworld reinforcement learning environments.
# output-file: index.html
# title: multigrid
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install multigrid in Development mode

# %% [markdown]
# ```sh
# # make sure multigrid package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to multigrid
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/Ahmed-Khaled-Saleh/multigrid.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c Ahmed-Khaled-Saleh multigrid
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install multigrid
# ```
#
#
# [repo]: https://github.com/Ahmed-Khaled-Saleh/multigrid
# [docs]: https://Ahmed-Khaled-Saleh.github.io/multigrid/
# [pypi]: https://pypi.org/project/multigrid/
# [conda]: https://anaconda.org/Ahmed-Khaled-Saleh/multigrid

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/Ahmed-Khaled-Saleh/multigrid
# [docs]: https://Ahmed-Khaled-Saleh.github.io/multigrid/
# [pypi]: https://pypi.org/project/multigrid/
# [conda]: https://anaconda.org/Ahmed-Khaled-Saleh/multigrid

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
